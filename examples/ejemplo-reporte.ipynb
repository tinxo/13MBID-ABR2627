# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### Sesión Práctica 01 - Ejemplo reporte con ydata-profiling
#
# ---
#
# En esta libreta se realizan una serie de pasos básicos para verificar la funcionalidad de generación de reportes con la librería seleccionada (ydata-profiling).

# %%
import pandas as pd
from ydata_profiling import ProfileReport

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    import pkg_resources
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#
# File ~/code/viu/13MBID/2026/13MBID-ABR2627/.venv/lib/python3.12/site-packages/ydata_profiling/__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/code/viu/13MBID/2026/13MBID-ABR2627/.venv/lib/python3.12/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~/code/viu/13MBID/2026/13MBID-ABR2627/.venv/lib/python3.12/site-packages/ydata_profiling/profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %% [markdown]
# Se realiza en primera instancia la lectura del conjunto de datos.

# %%
df_creditos = pd.read_csv("../data/raw/ejemplo.csv", sep=";")
df_creditos.head(5)

# %% [markdown]
# Se genera el reporte y se lo exporta a un archivo HTML

# %%
profile = ProfileReport(df_creditos, title="Reporte de verificación - Créditos")
profile.to_file("../docs/reporte_verificacion.html")
